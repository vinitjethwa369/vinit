# %% [markdown]
# <a href="https://colab.research.google.com/github/vinitjethwa369/vinit/blob/html/House_Pricing_Detection_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib
import seaborn as sns

# %%
data=pd.read_csv('kc_house_data.csv')

# %% [markdown]
# # New Section

# %% [markdown]
# # Exploring Data Analysis

# %%
data.shape
# Out:
# (21613, 21)

# %%
pd.set_option('display.float_format', '{:.2f}'.format) # Set the display format for float values

# %%
data.describe()
# Out:
#                  id      price  bedrooms  bathrooms  sqft_living   sqft_lot  \
# count      21613.00   21613.00  21613.00   21613.00     21613.00   21613.00
# mean  4580301520.86  540088.14      3.37       2.11      2079.90   15106.97
# std   2876565571.31  367127.20      0.93       0.77       918.44   41420.51
# min      1000102.00   75000.00      0.00       0.00       290.00     520.00
# 25%   2123049194.00  321950.00      3.00       1.75      1427.00    5040.00
# 50%   3904930410.00  450000.00      3.00       2.25      1910.00    7618.00
# 75%   7308900445.00  645000.00      4.00       2.50      2550.00   10688.00
# max   9900000190.00 7700000.00     33.00       8.00     13540.00 1651359.00
#
#         floors  waterfront     view  condition    grade  sqft_above  \
# count 21613.00    21613.00 21613.00   21613.00 21613.00    21613.00
# mean      1.49        0.01     0.23       3.41     7.66     1788.39
# std       0.54        0.09     0.77       0.65     1.18      828.09
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.isnull().sum() # to check wheather data has nay nulll value or not
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sns.boxplot(x='price',y='bathrooms' , data=data) #unused
# Out:
# <Axes: xlabel='price', ylabel='bathrooms'>

# %%
import seaborn as sns
import pandas as pd
# Create a distribution plot for the 'price' column
sns.distplot(data['price'])
 #unused
# Out:
# <ipython-input-16-9b8fdf944a5d>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# # Spliting of Data in X and Y for training and testing

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
X=data[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement',
      'sqft_living15', 'sqft_lot15']]

# %%
X
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650    1.00           0     0
# 1             3       2.25         2570      7242    2.00           0     0
# 2             2       1.00          770     10000    1.00           0     0
# 3             4       3.00         1960      5000    1.00           0     0
# 4             3       2.00         1680      8080    1.00           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131    3.00           0     0
# 21609         4       2.50         2310      5813    2.00           0     0
# 21610         2       0.75         1020      1350    2.00           0     0
# 21611         3       2.50         1600      2388    2.00           0     0
# 21612         2       0.75         1020      1076    2.00           0     0
#
# ...

# %%
Y= data['price']

# %%
Y
# Out:
# 0       221900.00
# 1       538000.00
# 2       180000.00
# 3       604000.00
# 4       510000.00
#            ...
# 21608   360000.00
# 21609   400000.00
# 21610   402101.00
# 21611   400000.00
# 21612   325000.00
# Name: price, Length: 21613, dtype: float64

# %%
from sklearn.model_selection import train_test_split # for using model

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y, test_size = 0.25, random_state=101)

# %%
X_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 19642         4       2.50         2070      4270    2.00           0     0
# 8626          3       2.25         1400      6970    2.00           0     0
# 6954          5       3.00         2190      4900    2.00           0     0
# 20242         4       2.50         2547      4800    2.00           0     0
# 10376         5       3.50         4060      8309    2.00           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 5695          3       2.25         1920      9672    2.00           0     0
# 8006          3       1.00         1240      3600    1.50           0     0
# 17745         3       2.25         1780      7332    2.00           0     0
# 17931         2       1.00         1150      5000    1.00           0     0
# 13151         3       1.00         1450      7930    1.00           0     0
#
# ...

# %%
Y_train
# Out:
# 19642   493000.00
# 8626    425000.00
# 6954    588000.00
# 20242   392440.00
# 10376   630000.00
#            ...
# 5695    625000.00
# 8006    390000.00
# 17745   272450.00
# 17931   552000.00
# 13151   394000.00
# Name: price, Length: 16209, dtype: float64

# %%
X_test
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 3834          2       1.00         1050      6317    1.50           0     0
# 1348          4       2.25         2040      9565    1.00           0     0
# 20366         4       2.50         2500      4000    2.00           0     0
# 16617         5       2.00         2360     19899    1.00           0     0
# 20925         3       3.00         1670      4440    1.00           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 7148          3       1.75         1520      5500    1.50           0     0
# 2747          5       3.00         2970     10335    2.00           0     0
# 15565         3       2.50         3440    103672    2.00           0     0
# 21238         3       2.50         1572      4000    2.00           0     0
# 2333          3       3.00         2920     23085    1.50           0     2
#
# ...

# %%
Y_test
# Out:
# 3834    349950.00
# 1348    450000.00
# 20366   635000.00
# 16617   355500.00
# 20925   246950.00
#            ...
# 7148    738000.00
# 2747    726000.00
# 15565   560000.00
# 21238   299000.00
# 2333    555000.00
# Name: price, Length: 5404, dtype: float64

# %% [markdown]
# # Normalization (use z-score / Scaling of data : to bring down the data at some particular stnadard where the mean becomes : 0 and std deviation becomes : 1) here we applying StandardScaling

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()

# %%
X_train_std = std.fit_transform(X_train)
X_test_std = std.transform(X_train)

# %%
X_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 19642         4       2.50         2070      4270    2.00           0     0
# 8626          3       2.25         1400      6970    2.00           0     0
# 6954          5       3.00         2190      4900    2.00           0     0
# 20242         4       2.50         2547      4800    2.00           0     0
# 10376         5       3.50         4060      8309    2.00           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 5695          3       2.25         1920      9672    2.00           0     0
# 8006          3       1.00         1240      3600    1.50           0     0
# 17745         3       2.25         1780      7332    2.00           0     0
# 17931         2       1.00         1150      5000    1.00           0     0
# 13151         3       1.00         1450      7930    1.00           0     0
#
# ...

# %%
X_test_std
# Out:
# array([[ 0.69608634,  0.49894508, -0.00810266, ..., -0.65896096,
#          0.12372791, -0.29371924],
#        [-0.40802008,  0.173745  , -0.74457445, ..., -0.65896096,
#         -0.27289927, -0.16524962],
#        [ 1.80019275,  1.14934525,  0.12380274, ...,  0.93301185,
#         -0.90456477, -0.29386481],
#        ...,
#        [-0.40802008,  0.173745  , -0.32687403, ..., -0.65896096,
#         -0.69890623, -0.18399236],
#        [-1.51212649, -1.45225542, -1.01937736, ..., -0.43153627,
#         -0.76794874, -0.3042734 ],
#        [-0.40802008, -1.45225542, -0.68961387, ...,  0.0233131 ,
#         -1.38933131, -0.17980708]])

# %%
Y_train
# Out:
# 19642   493000.00
# 8626    425000.00
# 6954    588000.00
# 20242   392440.00
# 10376   630000.00
#            ...
# 5695    625000.00
# 8006    390000.00
# 17745   272450.00
# 17931   552000.00
# 13151   394000.00
# Name: price, Length: 16209, dtype: float64

# %%
Y_test
# Out:
# 3834    349950.00
# 1348    450000.00
# 20366   635000.00
# 16617   355500.00
# 20925   246950.00
#            ...
# 7148    738000.00
# 2747    726000.00
# 15565   560000.00
# 21238   299000.00
# 2333    555000.00
# Name: price, Length: 5404, dtype: float64

# %% [markdown]
# # DATA TRAINING IS DONE NOW MODEL TRAINING STARt

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()

# %%
lr.fit(X_train , Y_train) # for learninig/training X and Y data to model
# Out:
# LinearRegression()

# %%
Y_pred=lr.predict(X_test)  # model is now capable for predicting the data

# %%
Y_pred
# Out:
# array([356776.02589282, 511927.33428651, 573736.52389145, ...,
#        824101.44697811, 437013.51415352, 731915.8217072 ])

# %%
X_test
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 3834          2       1.00         1050      6317    1.50           0     0
# 1348          4       2.25         2040      9565    1.00           0     0
# 20366         4       2.50         2500      4000    2.00           0     0
# 16617         5       2.00         2360     19899    1.00           0     0
# 20925         3       3.00         1670      4440    1.00           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 7148          3       1.75         1520      5500    1.50           0     0
# 2747          5       3.00         2970     10335    2.00           0     0
# 15565         3       2.50         3440    103672    2.00           0     0
# 21238         3       2.50         1572      4000    2.00           0     0
# 2333          3       3.00         2920     23085    1.50           0     2
#
# ...

# %%
from sklearn.metrics import mean_absolute_error,r2_score

# %%
mean_absolute_error(Y_test,Y_pred)
# Out:
# 151500.53601089356

# %%
Y_test
# Out:
# 3834    349950.00
# 1348    450000.00
# 20366   635000.00
# 16617   355500.00
# 20925   246950.00
#            ...
# 7148    738000.00
# 2747    726000.00
# 15565   560000.00
# 21238   299000.00
# 2333    555000.00
# Name: price, Length: 5404, dtype: float64

# %%
X_test.loc[7148]
# Out:
# bedrooms           3.00
# bathrooms          1.75
# sqft_living     1520.00
# sqft_lot        5500.00
# floors             1.50
# waterfront         0.00
# view               0.00
# condition          5.00
# grade              7.00
# sqft_above      1520.00
# sqft_basement      0.00
# sqft_living15   2310.00
# sqft_lot15      5500.00
# Name: 7148, dtype: float64

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.6211653492243865

# %% [markdown]
# # Predict for the single house

# %%
#prediction fro singlle house by puting the above 15 perameters
int(lr.predict([[3,1,1520,5500,1,0,0,3,8,1000,1,2000,5000]]))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 433441
